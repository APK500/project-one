# %%
import os
import csv
import pandas as pd
import numpy as np

# %%
# data file's path:
crime_data = "Crime_by_City_2017to2015_from_table8_and_table4.csv"

# %%
# Use Pandas to read data
crime_data_df = pd.read_csv(crime_data)
crime_data_df.head()
# Out:
#      State        City  2017 Population 2017 Violent Crime  2017 Murder  \
# 0  Alabama  Birmingham              NaN              1,845           42
# 1  Alabama      Mobile              NaN                925           20
# 2  Alabama  Montgomery              NaN                656           19
# 3   Alaska   Anchorage              NaN              1,707           13
# 4  Arizona    Chandler              NaN                303            1
#
#   2017 Rape 2017 Robbery 2017 Aggravated Assault 2017 Property Crime Total  \
# 0        92          472                   1,223                     6,458
# 1        53          235                     617                     6,482
# 2        35          185                     417                     4,246
# 3       196          369                   1,129                     7,708
# 4        67           72                     163                     2,906
#
#   2017 Burglary    ...     2015 Murder 2015 Rape  2015 Robbery  \
# ...

# %%
# Reference a single column within a DataFrame  (based on the above)
crime_data_df[["City","State","2017 Violent Crime Total","2017 Property Crime Total","2017 All Crimes Total","2016 Population","2016 Violent Crime","2016 Property Crime Total","2016 All Crimes Total","2015 Violent Crime Total","2015 Property Crime Total","2015 All Crimes Total" ]].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-62d8a694f2b0> in <module>()
#       1 # Reference a single column within a DataFrame  (based on the above)
# ----> 2 crime_data_df[["City","State","2017 Violent Crime","2017 Property Crime Total","2017 Total","2016 Violent Crime","2016 Property Crime Total","2016 Total","2015 Violent Crime","2015 Property Crime Total","2015 Total" ]].head()
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2131         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2132             # either boolean or fancy integer index
# -> 2133             return self._getitem_array(key)
#    2134         elif isinstance(key, DataFrame):
#    2135             return self._getitem_frame(key)
#
# ...
