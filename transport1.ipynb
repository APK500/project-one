# %%
import os
import csv
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
from scipy import stats
import matplotlib.pyplot as plt

# ##The average commute time for transit users.
# Percentage difference between average commute times of car commuters and transit users.
# Percentage of commuters who use public transit.
# Total number of commuters who use public transit.
# The difference between the citywide median income and the median income of transit users.

# %%
##All csvs

commutercsv = "commutertimes1.csv"
commuterpubliccsv = "commutertimespublic.csv"
populationcsv = "population1.csv"
citiescsv = "cities1.csv"
commuting_driving = "commutingdriving.csv"

# %%
##Reading the csvs, changing some names of columns to match certain csvs, making the cities lower case, the "thousands = ,"makes sure that the string 1,200 is a number

commuter_df = pd.read_csv(commutercsv, thousands = ",")
commuter_public_df = pd.read_csv(commuterpubliccsv, thousands = ",")
population_df = pd.read_csv(populationcsv, thousands = ",")
cities_df = pd.read_csv(citiescsv)
commuting_driving_df = pd.read_csv(commuting_driving, thousands = ",")
new_pop_df = population_df[["NAME","STNAME","POPESTIMATE2016"]]
cities_df=cities_df.rename(columns={"City/Region": "City"})
commuter_public_df["City"]=commuter_public_df["City"].str.lower()
commuting_driving_df["City"]= commuting_driving_df["City"].str.lower()
cities_df["City"]=cities_df["City"].str.lower()
commuter_df["City"]=commuter_df["City"].str.lower()
new_pop_df["NAME"]=new_pop_df["NAME"].str.lower()
commuting_driving_df = commuting_driving_df.dropna(axis=0,how="any")

# %%
##This is the dataset of all cities and average commute time for driving in minutes
commuter_df.head()
# Out:
#           ID        Country           GeoID      City State Area Type  \
# 0  0100000US  United States  310M300US10100  aberdeen    SD     Micro
# 1  0100000US  United States  310M300US10140  aberdeen    WA     Micro
# 2  0100000US  United States  310M300US10180   abilene    TX     Metro
# 3  0100000US  United States  310M300US10220       ada    OK     Micro
# 4  0100000US  United States  310M300US10300    adrian    MI     Micro
#
#    Minutes  Margin of Error
# 0     13.2              0.5
# 1     24.8              1.0
# 2     17.4              0.5
# 3     17.3              0.6
# 4     26.5              0.7

# %%
##Populatino estimates for each city and state
new_pop_df.head()
# Out:
#               NAME   STNAME  POPESTIMATE2016
# 0          alabama  Alabama          4863300
# 1   abbeville city  Alabama             2603
# 2  adamsville city  Alabama             4360
# 3     addison town  Alabama              738
# 4       akron town  Alabama              334

# %%
##List of Cities of interest
cities_df.head()
# Out:
#        City State
# 0   atlanta    GA
# 1    austin    TX
# 2    boston    MA
# 3   chicago    IL
# 4  columbus    OH

# %%
##Public transportation data (needs cleaning)
commuter_public_df.head()
# Out:
#                         Name      City State Legacy NTD ID NTD ID  \
# 0  MTA New York City Transit  new york    NY          2008  20008
# 1  MTA New York City Transit  new york    NY          2008  20008
# 2  MTA New York City Transit  new york    NY          2008  20008
# 3  MTA New York City Transit  new york    NY          2008  20008
# 4  MTA New York City Transit  new york    NY          2008  20008
#
#                                    Organization Type NTD Reporter Type  \
# 0  Subsidiary Unit of a Transit Agency, Reporting...     Full Reporter
# 1  Subsidiary Unit of a Transit Agency, Reporting...     Full Reporter
# 2  Subsidiary Unit of a Transit Agency, Reporting...     Full Reporter
# 3  Subsidiary Unit of a Transit Agency, Reporting...     Full Reporter
# 4  Subsidiary Unit of a Transit Agency, Reporting...     Full Reporter
#
#    Primary UZA Population  Agency VOMS Mode     ...      Unnamed: 37  \
# 0                18351295        11004   HR     ...              NaN
# 1                18351295        11004   MB     ...              NaN
# 2                18351295        11004   DR     ...              NaN
# 3                18351295        11004   CB     ...              NaN
# 4                18351295        11004   RB     ...              NaN
#
#    Unnamed: 38  Unnamed: 39 Unnamed: 40 Unnamed: 41 Unnamed: 42  Unnamed: 43  \
# 0          NaN          NaN         NaN         NaN         NaN          NaN
# 1          NaN          NaN         NaN         NaN         NaN          NaN
# 2          NaN          NaN         NaN         NaN         NaN          NaN
# 3          NaN          NaN         NaN         NaN         NaN          NaN
# 4          NaN          NaN         NaN         NaN         NaN          NaN
#
#    Unnamed: 44  Unnamed: 45  Unnamed: 46
# 0          NaN          NaN          NaN
# 1          NaN          NaN          NaN
# 2          NaN          NaN          NaN
# 3          NaN          NaN          NaN
# 4          NaN          NaN          NaN
#
# [5 rows x 47 columns]

# %%
##Creating neww columns in the cities_df 
cities_df["Average Public Transport Commute (minutes)"]= ""
cities_df["Average Individual Commute (distance)"] = ""
cities_df["Population"] = ""
cities_df["Population Served"]=""

# %%
##getting rid of unwanted columns
try:
    for i in range(30,47):
        del commuter_public_df[commuter_public_df.columns[i]]
except IndexError:
    pass

# %%
##Yes this is the same cell as before..run it
try:
    for i in range(30,47):
        del commuter_public_df[commuter_public_df.columns[i]]
except IndexError:
    pass

# %%
##Still getting rid of them...
del commuter_public_df["Unnamed: 33"]
del commuter_public_df["Unnamed: 37"]

# %%
#And...that's better
del commuter_public_df["Unnamed: 41"]
del commuter_public_df["Unnamed: 45"]

# %%
##Extracting from the csv, the total number of people that use car, truck or public transportation. We only want our cities of interest

list_of_df3 = []
merged_df3 = []
for index,row in cities_df.iterrows():
    ge3 = commuting_driving_df[commuting_driving_df["City"].str.contains(row["City"])]
    ga3 = ge3[ge3["State"].str.contains(row["State"])][["City","State","Mode of Transport","Total People","Margin of Error"]]
 #   print(row["State"])
    list_of_df3.append(ga3)
    
merged_df3 = pd.concat(list_of_df3)
merged_df3
# Out:
#                                    City          State  \
# 49        atlanta-sandy springs-roswell            GA
# 50        atlanta-sandy springs-roswell            GA
# 51        atlanta-sandy springs-roswell            GA
# 237       atlanta-sandy springs-roswell            GA
# 238       atlanta-sandy springs-roswell            GA
# 260       atlanta-sandy springs-roswell            GA
# 261       atlanta-sandy springs-roswell            GA
# 262       atlanta-sandy springs-roswell            GA
# 265       atlanta-sandy springs-roswell            GA
# 266       atlanta-sandy springs-roswell            GA
# 290       atlanta-sandy springs-roswell            GA
# 291       atlanta-sandy springs-roswell            GA
# 292       atlanta-sandy springs-roswell            GA
# 293       atlanta-sandy springs-roswell            GA
# 296       atlanta-sandy springs-roswell            GA
# 297       atlanta-sandy springs-roswell            GA
# 426       atlanta-sandy springs-roswell            GA
# 427       atlanta-sandy springs-roswell            GA
# 428       atlanta-sandy springs-roswell            GA
# 429       atlanta-sandy springs-roswell            GA
# 430       atlanta-sandy springs-roswell            GA
# 433       atlanta-sandy springs-roswell            GA
# 434       atlanta-sandy springs-roswell            GA
# 435       atlanta-sandy springs-roswell            GA
# 436       atlanta-sandy springs-roswell            GA
# 437       atlanta-sandy springs-roswell            GA
# 438       atlanta-sandy springs-roswell            GA
# 469       atlanta-sandy springs-roswell            GA
# 470       atlanta-sandy springs-roswell            GA
# 500       atlanta-sandy springs-roswell            GA
# ...                                 ...            ...
# 99381   washington-arlington-alexandria   DC-VA-MD-WV
# 99384   washington-arlington-alexandria   DC-VA-MD-WV
# 99385   washington-arlington-alexandria   DC-VA-MD-WV
# 99386   washington-arlington-alexandria   DC-VA-MD-WV
# 99387   washington-arlington-alexandria   DC-VA-MD-WV
# 99388   washington-arlington-alexandria   DC-VA-MD-WV
# 99389   washington-arlington-alexandria   DC-VA-MD-WV
# 99390   washington-arlington-alexandria   DC-VA-MD-WV
# 99391   washington-arlington-alexandria   DC-VA-MD-WV
# 99393   washington-arlington-alexandria   DC-VA-MD-WV
# 99398   washington-arlington-alexandria   DC-VA-MD-WV
# 99399   washington-arlington-alexandria   DC-VA-MD-WV
# 99400   washington-arlington-alexandria   DC-VA-MD-WV
# 99401   washington-arlington-alexandria   DC-VA-MD-WV
# 99419   washington-arlington-alexandria   DC-VA-MD-WV
# 99420   washington-arlington-alexandria   DC-VA-MD-WV
# 99639   washington-arlington-alexandria   DC-VA-MD-WV
# 99686   washington-arlington-alexandria   DC-VA-MD-WV
# 99687   washington-arlington-alexandria   DC-VA-MD-WV
# 99688   washington-arlington-alexandria   DC-VA-MD-WV
# 99730   washington-arlington-alexandria   DC-VA-MD-WV
# 99733   washington-arlington-alexandria   DC-VA-MD-WV
# 99734   washington-arlington-alexandria   DC-VA-MD-WV
# 99735   washington-arlington-alexandria   DC-VA-MD-WV
# 99736   washington-arlington-alexandria   DC-VA-MD-WV
# 99745   washington-arlington-alexandria   DC-VA-MD-WV
# 99746   washington-arlington-alexandria   DC-VA-MD-WV
# 99752   washington-arlington-alexandria   DC-VA-MD-WV
# 102501  washington-arlington-alexandria   DC-VA-MD-WV
# 102502  washington-arlington-alexandria   DC-VA-MD-WV
#
#                       Mode of Transport  Total People  Margin of Error
# 49      Car, truck, or van: Drove alone            34               55
# 50                    Other travel mode            30               45
# 51      Car, truck, or van: Drove alone            79               63
# 237     Car, truck, or van: Drove alone            51               35
# 238       Car, truck, or van: Carpooled            16               26
# 260     Car, truck, or van: Drove alone            50               45
# 261     Car, truck, or van: Drove alone            42               35
# 262       Car, truck, or van: Carpooled            10               16
# 265     Car, truck, or van: Drove alone            35               40
# 266       Car, truck, or van: Carpooled            11               18
# 290     Car, truck, or van: Drove alone           138              100
# 291       Car, truck, or van: Carpooled            65              100
# 292               Public transportation             9               15
# 293                   Other travel mode            13               19
# 296     Car, truck, or van: Drove alone            22               24
# 297       Car, truck, or van: Carpooled             7               10
# 426     Car, truck, or van: Drove alone           937              183
# 427       Car, truck, or van: Carpooled           215               99
# 428     Car, truck, or van: Drove alone            68               50
# 429       Car, truck, or van: Carpooled            12               16
# 430     Car, truck, or van: Drove alone            30               24
# 433     Car, truck, or van: Drove alone            53               38
# 434       Car, truck, or van: Carpooled             8               15
# 435     Car, truck, or van: Drove alone           350              112
# 436       Car, truck, or van: Carpooled             8               14
# 437     Car, truck, or van: Drove alone            16               22
# 438       Car, truck, or van: Carpooled             4                8
# 469     Car, truck, or van: Drove alone            21               17
# 470                   Other travel mode             2                3
# 500     Car, truck, or van: Drove alone           118               90
# ...                                 ...           ...              ...
# 99381   Car, truck, or van: Drove alone            63               50
# 99384   Car, truck, or van: Drove alone          3036              389
# 99385     Car, truck, or van: Carpooled          1010              257
# 99386                 Other travel mode             9               14
# 99387   Car, truck, or van: Drove alone           184              100
# 99388     Car, truck, or van: Carpooled             2                3
# 99389   Car, truck, or van: Drove alone           112               74
# 99390     Car, truck, or van: Carpooled             8               18
# 99391                 Other travel mode            24               29
# 99393   Car, truck, or van: Drove alone            42               35
# 99398   Car, truck, or van: Drove alone          8064              541
# 99399     Car, truck, or van: Carpooled           994              243
# 99400             Public transportation             4                8
# 99401                 Other travel mode          2357              321
# 99419     Car, truck, or van: Carpooled             3                6
# 99420             Public transportation            11               14
# 99639   Car, truck, or van: Drove alone            72               89
# 99686   Car, truck, or van: Drove alone            10               16
# 99687     Car, truck, or van: Carpooled            11               16
# 99688                 Other travel mode             9               13
# 99730   Car, truck, or van: Drove alone            25               27
# 99733   Car, truck, or van: Drove alone           198              115
# 99734     Car, truck, or van: Carpooled           201              240
# 99735   Car, truck, or van: Drove alone            45               48
# 99736     Car, truck, or van: Carpooled            23               35
# 99745   Car, truck, or van: Drove alone            12               13
# 99746     Car, truck, or van: Carpooled            25               38
# 99752   Car, truck, or van: Drove alone            59               49
# 102501  Car, truck, or van: Drove alone            10               11
# 102502    Car, truck, or van: Carpooled            27               34
#
# [23734 rows x 5 columns]

# %%
##For this data set, we are only concerned about people that are using their cars. So, we need to get rid of rows with public transport and "other travel mode"

merged_df3_drive_only=merged_df3[merged_df3["Mode of Transport"]!="Public transportation"]
merged_df3_drive_only=merged_df3_drive_only[merged_df3_drive_only["Mode of Transport"]!="Other travel mode"]

# %%
##Camden and Rockville are considered interchangeable due to how close they are in MD, and they both reside in Montgomery county
##sums_driving is a dctionary that counts up how many people drive to work per day, and the keys are the cities

sums_driving = {}
cities_df.set_value(10, 'City', "camden")
for index,row in cities_df.iterrows():
    sum_of_people = merged_df3_drive_only[merged_df3_drive_only["City"].str.contains(row["City"])]
    sum_of_driving_people = sum_of_people[sum_of_people["State"].str.contains(row["State"])]
    sums_driving[row["City"]]=sum_of_driving_people["Total People"].sum()

cities_df = cities_df.set_value(10,"City","rockville")
# Out:
# {'alexandria': 4830932,
#  'atlanta': 2143375,
#  'austin': 774492,
#  'boston': 1912936,
#  'camden': 2207525,
#  'chicago': 3509505,
#  'columbus': 857407,
#  'dallas': 2850110,
#  'denver': 1095293,
#  'indianapolis': 828224,
#  'los angeles': 5103600,
#  'miami': 2235321,
#  'nashville': 751647,
#  'new york': 10578606,
#  'newark': 10578606,
#  'philadelphia': 2207525,
#  'pittsburgh': 959786,
#  'raleigh': 487275,
#  'washington': 4830932}

# %%
##sum_driving needs to be converted into a dictionary, with an index

sum_driving_df = pd.DataFrame.from_dict(sums_driving, orient = "index")
sum_driving_df = sum_driving_df.rename(columns = {0:"Total People per year"})

# %%
sum_driving_df
# Out:
#             City  Average People per Hour
# 0        atlanta               244.677511
# 1         austin                88.412329
# 2         boston               218.371689
# 3        chicago               400.628425
# 4       columbus                97.877511
# 5         dallas               325.355023
# 6         denver               125.033447
# 7   indianapolis                94.546119
# 8    los angeles               582.602740
# 9          miami               255.173630
# 10     rockville               252.000571
# 11     nashville                85.804452
# 12        newark              1207.603425
# 13      new york              1207.603425
# 14    alexandria               551.476256
# 15  philadelphia               252.000571
# 16    pittsburgh               109.564612
# 17       raleigh                55.625000
# 18    washington               551.476256

# %%
##Making sure the cities are not the index, but an actual index
sum_driving_df.reset_index(level=0, inplace=True)

# %%
sum_driving_df = sum_driving_df.rename(columns = {"index":"City"})

# %%
sum_driving_df.set_value(10,"City","rockville")
# Out:
#             City  Total People per year
# 0        atlanta                2143375
# 1         austin                 774492
# 2         boston                1912936
# 3        chicago                3509505
# 4       columbus                 857407
# 5         dallas                2850110
# 6         denver                1095293
# 7   indianapolis                 828224
# 8    los angeles                5103600
# 9          miami                2235321
# 10     rockville                2207525
# 11     nashville                 751647
# 12        newark               10578606
# 13      new york               10578606
# 14    alexandria                4830932
# 15  philadelphia                2207525
# 16    pittsburgh                 959786
# 17       raleigh                 487275
# 18    washington                4830932

# %%
##Adding another row, the future data sets have "passengers per hour" so this makes it consistent
sum_driving_df["Average People per Hour"] = (sum_driving_df["Total People per year"]/365)/24

# %%
#We no longer need this column
del sum_driving_df["Total People per year"]

# %%
##Tranporation mode symbols
##Mode Symbol:
##CB: Commuter Bus
##DR: Demand Response
##HR: Heavy Rail
##FB: Ferryboat
##MB: Bus
##CB: Commuter Bus
##DT: Demand Response Taxi (how NY has none of this..)
##CR: Commuter Rail
##VP: Vanpool
##LR: Light Rail
##SR: Streetcar Rail
##TB: Trolleybus
##RB: Bus Rapid Transit
##MG: Monorail/Automated Guideway
##YR: Hybrid Rail

# %%
##Extracting the data we need from the commuter public tranport data
list_of_df = []
for index,row in cities_df.iterrows():
    ge = commuter_public_df[commuter_public_df["City"]==row["City"]]
    ga = ge[ge["State"].str.contains(row["State"])][["City","State","Mode","Average Speed (mi/hr)","Passengers per Hour","Average Passenger Trip Length (mi)","Directional Route Miles"]]
    list_of_df.append(ga)

# %%
##Combining the data frame into one
merged_df = pd.concat(list_of_df)
merged_df
# Out:
#               City State Mode Average Speed (mi/hr) Passengers per Hour  \
# 110        atlanta    GA   MB                12.33               29.75
# 111        atlanta    GA   HR                26.56               85.81
# 112        atlanta    GA   DR                15.40                1.58
# 113        atlanta    GA   DR                17.47                1.71
# 314        atlanta    GA   VP                42.11                6.87
# 590        atlanta    GA   CB                25.57               15.00
# 1064       atlanta    GA   VP                51.14                4.70
# 3372       atlanta    GA   SR                 4.83               52.42
# 146         austin    TX   MB                11.85               23.39
# 147         austin    TX   VP                35.87                4.99
# 148         austin    TX   DR                13.16                1.72
# 149         austin    TX   CB                18.34               13.50
# 150         austin    TX   DT                21.83                3.85
# 151         austin    TX   YR                23.80               64.32
# 546         austin    TX   DR                23.51                1.96
# 549         austin    TX   CB                23.84                4.69
# 551         austin    TX   MB                13.75                2.35
# 2493        austin    TX   MB                14.32                3.66
# 2513        austin    TX   DR                10.67                2.51
# 33          boston    MA   MB                10.37               51.59
# 34          boston    MA   DR                13.99                1.72
# 35          boston    MA   CR                29.98               43.10
# 36          boston    MA   HR                15.27              114.67
# 37          boston    MA   LR                 9.24               91.79
# 38          boston    MA   RB                 8.43               90.04
# 39          boston    MA   TB                 9.05               46.19
# 40          boston    MA   MB                11.70               24.57
# 41          boston    MA   FB                 9.79               62.31
# 641         boston    MA   VP                39.71                5.16
# 3672        boston    MA   MB                 6.97                4.22
# ...            ...   ...  ...                   ...                 ...
# 1383      new york    NY   MB                26.89               26.54
# 1395      new york    NY   FB                 9.80            1,165.53
# 2929      new york    NY   FB                12.73               86.90
# 3316      new york    NY   FB                10.43              169.66
# 601     alexandria    VA   MB                 8.48               19.98
# 602     alexandria    VA   DT                14.33                3.01
# 608     alexandria    VA   CR                31.94               60.73
# 42    philadelphia    PA   MB                10.03               46.01
# 43    philadelphia    PA   DR                10.27                1.63
# 44    philadelphia    PA   CR                21.10               39.49
# 45    philadelphia    PA   HR                18.53              109.32
# 46    philadelphia    PA   SR                 8.53               66.47
# 47    philadelphia    PA   TB                 8.49               63.03
# 127     pittsburgh    PA   MB                13.12               33.78
# 128     pittsburgh    PA   DR                14.86                2.38
# 129     pittsburgh    PA   LR                12.73               47.68
# 130     pittsburgh    PA   IP                 2.34               99.36
# 894     pittsburgh    PA   VP                38.10                9.05
# 3367    pittsburgh    PA   DR                13.65                6.32
# 292        raleigh    NC   DT                 5.45                0.95
# 294        raleigh    NC   MB                12.82               22.87
# 990        raleigh    NC   DR                21.65                1.63
# 1293       raleigh    NC   MB                10.44               44.58
# 19      washington    DC   MB                10.15               32.92
# 20      washington    DC   HR                24.60               78.61
# 21      washington    DC   DR                 9.89                1.14
# 22      washington    DC   DT                23.46                1.42
# 895     washington    DC   MB                 5.72               24.85
# 900     washington    DC   SR                 4.31               36.73
# 1770    washington    DC   VP                39.05                6.37
#
#      Average Passenger Trip Length (mi)  Directional Route Miles
# 110                               4.25                    1672.2
# 111                               6.63                      96.1
# 112                              10.91                       0.0
# 113                              13.16                       0.0
# 314                              41.16                       0.0
# 590                              25.19                     270.4
# 1064                             62.38                       0.0
# 3372                              0.84                       2.7
# 146                               4.07                    1084.8
# 147                              34.13                       0.0
# 148                               7.96                       0.0
# 149                              16.25                     192.2
# 150                               6.54                       0.0
# 151                              16.42                      64.2
# 546                                -                         0.0
# 549                                -                         0.0
# 551                                -                         0.0
# 2493                               -                         0.0
# 2513                               -                         0.0
# 33                                2.63                    1493.5
# 34                                7.79                       0.0
# 35                               20.63                     776.1
# 36                                3.51                      76.3
# 37                                2.66                      51.0
# 38                                1.83                      10.4
# 39                                2.17                      21.6
# 40                                2.32                      80.0
# 41                                8.20                      38.4
# 641                              38.84                       0.0
# 3672                               -                         0.0
# ...                                 ...                      ...
# 1383                              7.47                      33.0
# 1395                              5.20                      10.4
# 2929                              1.95                      15.7
# 3316                              2.20                      11.0
# 601                               2.25                     111.1
# 602                               5.11                       0.0
# 608                              33.49                     173.6
# 42                                3.22                    2503.1
# 43                                6.98                       0.0
# 44                               12.59                     446.9
# 45                                4.44                      74.9
# 46                                2.43                      82.9
# 47                                1.94                      30.6
# 127                               4.27                    1644.2
# 128                               7.85                       0.0
# 129                               3.75                      49.6
# 130                               0.12                       0.2
# 894                              27.66                       0.0
# 3367                               -                         0.0
# 292                               6.55                       0.0
# 294                               4.39                     408.1
# 990                              13.44                       0.0
# 1293                              2.03                     312.9
# 19                                3.12                    2356.5
# 20                                5.92                     234.2
# 21                                7.87                       0.0
# 22                               16.51                       0.0
# 895                               1.10                      43.0
# 900                               0.94                       3.8
# 1770                               -                         0.0
#
# [130 rows x 7 columns]

# %%
##Changing data types to floats so that calculations can be made
merged_df["Average Speed (mi/hr)"] = merged_df["Average Speed (mi/hr)"].astype(float)

# %%
##This is a pain, but we need this to get rid of the rows that have a -  in the cell
##YOU NEED THIS PART
part1 = ~merged_df["Average Passenger Trip Length (mi)"].str.contains("-")

# %%
##Concating the true false
list2 = [merged_df,part1]
merged_df1 = pd.concat(list2)
merged_df["This"] = part1

# %%
merged_df2 = merged_df[merged_df["This"]==True]

# %%
del merged_df2["This"]

# %%
merged_df2
# Out:
#               City State Mode  Average Speed (mi/hr) Passengers per Hour  \
# 110        atlanta    GA   MB                  12.33              29.75
# 111        atlanta    GA   HR                  26.56              85.81
# 112        atlanta    GA   DR                  15.40               1.58
# 113        atlanta    GA   DR                  17.47               1.71
# 314        atlanta    GA   VP                  42.11               6.87
# 590        atlanta    GA   CB                  25.57              15.00
# 1064       atlanta    GA   VP                  51.14               4.70
# 3372       atlanta    GA   SR                   4.83              52.42
# 146         austin    TX   MB                  11.85              23.39
# 147         austin    TX   VP                  35.87               4.99
# 148         austin    TX   DR                  13.16               1.72
# 149         austin    TX   CB                  18.34              13.50
# 150         austin    TX   DT                  21.83               3.85
# 151         austin    TX   YR                  23.80              64.32
# 33          boston    MA   MB                  10.37              51.59
# 34          boston    MA   DR                  13.99               1.72
# 35          boston    MA   CR                  29.98              43.10
# 36          boston    MA   HR                  15.27             114.67
# 37          boston    MA   LR                   9.24              91.79
# 38          boston    MA   RB                   8.43              90.04
# 39          boston    MA   TB                   9.05              46.19
# 40          boston    MA   MB                  11.70              24.57
# 41          boston    MA   FB                   9.79              62.31
# 641         boston    MA   VP                  39.71               5.16
# 31         chicago    IL   MB                   9.08              44.98
# 32         chicago    IL   HR                  17.93              59.59
# 108        chicago    IL   CR                  30.45              50.57
# 241       columbus    OH   MB                  12.14              18.31
# 242       columbus    OH   DR                  19.35               1.55
# 1341      columbus    OH   VP                  47.48               5.36
# ...            ...   ...  ...                    ...                 ...
# 91        new york    NY   FB                  11.52              44.99
# 92        new york    NY   MB                   8.43              39.08
# 1383      new york    NY   MB                  26.89              26.54
# 1395      new york    NY   FB                   9.80           1,165.53
# 2929      new york    NY   FB                  12.73              86.90
# 3316      new york    NY   FB                  10.43             169.66
# 601     alexandria    VA   MB                   8.48              19.98
# 602     alexandria    VA   DT                  14.33               3.01
# 608     alexandria    VA   CR                  31.94              60.73
# 42    philadelphia    PA   MB                  10.03              46.01
# 43    philadelphia    PA   DR                  10.27               1.63
# 44    philadelphia    PA   CR                  21.10              39.49
# 45    philadelphia    PA   HR                  18.53             109.32
# 46    philadelphia    PA   SR                   8.53              66.47
# 47    philadelphia    PA   TB                   8.49              63.03
# 127     pittsburgh    PA   MB                  13.12              33.78
# 128     pittsburgh    PA   DR                  14.86               2.38
# 129     pittsburgh    PA   LR                  12.73              47.68
# 130     pittsburgh    PA   IP                   2.34              99.36
# 894     pittsburgh    PA   VP                  38.10               9.05
# 292        raleigh    NC   DT                   5.45               0.95
# 294        raleigh    NC   MB                  12.82              22.87
# 990        raleigh    NC   DR                  21.65               1.63
# 1293       raleigh    NC   MB                  10.44              44.58
# 19      washington    DC   MB                  10.15              32.92
# 20      washington    DC   HR                  24.60              78.61
# 21      washington    DC   DR                   9.89               1.14
# 22      washington    DC   DT                  23.46               1.42
# 895     washington    DC   MB                   5.72              24.85
# 900     washington    DC   SR                   4.31              36.73
#
#      Average Passenger Trip Length (mi)  Directional Route Miles
# 110                               4.25                    1672.2
# 111                               6.63                      96.1
# 112                              10.91                       0.0
# 113                              13.16                       0.0
# 314                              41.16                       0.0
# 590                              25.19                     270.4
# 1064                             62.38                       0.0
# 3372                              0.84                       2.7
# 146                               4.07                    1084.8
# 147                              34.13                       0.0
# 148                               7.96                       0.0
# 149                              16.25                     192.2
# 150                               6.54                       0.0
# 151                              16.42                      64.2
# 33                                2.63                    1493.5
# 34                                7.79                       0.0
# 35                               20.63                     776.1
# 36                                3.51                      76.3
# 37                                2.66                      51.0
# 38                                1.83                      10.4
# 39                                2.17                      21.6
# 40                                2.32                      80.0
# 41                                8.20                      38.4
# 641                              38.84                       0.0
# 31                                2.45                    1538.3
# 32                                6.06                     207.8
# 108                              22.37                     975.0
# 241                               3.83                    1099.4
# 242                              10.78                       0.0
# 1341                             47.82                       0.0
# ...                                 ...                      ...
# 91                                4.07                      13.2
# 92                                2.94                     811.0
# 1383                              7.47                      33.0
# 1395                              5.20                      10.4
# 2929                              1.95                      15.7
# 3316                              2.20                      11.0
# 601                               2.25                     111.1
# 602                               5.11                       0.0
# 608                              33.49                     173.6
# 42                                3.22                    2503.1
# 43                                6.98                       0.0
# 44                               12.59                     446.9
# 45                                4.44                      74.9
# 46                                2.43                      82.9
# 47                                1.94                      30.6
# 127                               4.27                    1644.2
# 128                               7.85                       0.0
# 129                               3.75                      49.6
# 130                               0.12                       0.2
# 894                              27.66                       0.0
# 292                               6.55                       0.0
# 294                               4.39                     408.1
# 990                              13.44                       0.0
# 1293                              2.03                     312.9
# 19                                3.12                    2356.5
# 20                                5.92                     234.2
# 21                                7.87                       0.0
# 22                               16.51                       0.0
# 895                               1.10                      43.0
# 900                               0.94                       3.8
#
# [115 rows x 7 columns]

# %%
##Setting more data types for calcuations
merged_df2[["Average Passenger Trip Length (mi)","Average Speed (mi/hr)"]] = merged_df2[["Average Passenger Trip Length (mi)","Average Speed (mi/hr)"]].astype(float)

# %%
##Calculating the average trip length

merged_df2['Average Trip Time'] = (merged_df2["Average Passenger Trip Length (mi)"]/merged_df2["Average Speed (mi/hr)"])*60

# %%
##Mode Symbol:
##CB: Commuter Bus
##DR: Demand Response
##HR: Heavy Rail
##FB: Ferryboat
##MB: Bus
##CB: Commuter Bus
##DT: Demand Response Taxi (how NY has none of this..)
##CR: Commuter Rail
##VP: Vanpool
##LR: Light Rail
##SR: Streetcar Rail
##TB: Trolleybus
##RB: Bus Rapid Transit
##MG: Monorail/Automated Guideway
##YR: Hybrid Rail

##because new york sucks...
merged_df2 = merged_df2.set_value(1395, 'Passengers per Hour', 1165.53)

# %%
##You need this too
##Setting mroe data types for calculations

merged_df2["Passengers per Hour"] = merged_df2["Passengers per Hour"].astype(float)

# %%
# d1["Passengers per Hour"] = d1["Passengers per Hour"].astype(float)
# sum1 = d1["Passengers per Hour"].sum()

# d1["Percentage of Passengers utilized"] = d1["Passengers per Hour"]/sum1

# d1["weighted"] = d1["Percentage of Passengers utilized"]*d1["Average Trip Time"] 

# weighted_score = d1["weighted"].sum()

# d1

list_of_df1 = []

###Doing the commuter driving concatanation

for index,row in cities_df.iterrows():
    ge1 = commuter_df[commuter_df["City"].str.contains(row["City"])]
    ga1 = ge1[ge1["State"].str.contains(row["State"])][["City","State","Minutes"]]
    list_of_df1.append(ga1)

commmuting_merged_df = pd.concat(list_of_df1)

commmuting_merged_df
##Droppinng rows we do not need
commmuting_merged_df=commmuting_merged_df.drop(105)
commmuting_merged_df=commmuting_merged_df.drop(168)
commmuting_merged_df=commmuting_merged_df.drop(220)
commmuting_merged_df=commmuting_merged_df.drop(510)
commmuting_merged_df=commmuting_merged_df.drop(563)
commmuting_merged_df=commmuting_merged_df.drop(624)
commmuting_merged_df=commmuting_merged_df.drop(686)
# commmuting_merged_df=commmuting_merged_df.drop(921)


##Setting the cities equal to the correct string, so that they can be combined later

for index,row in cities_df.iterrows():
    for index3,row3 in commmuting_merged_df.iterrows():
        if commmuting_merged_df["City"].str.contains(row["City"])[index3]:
            commmuting_merged_df.set_value(index3,"City",row["City"])

# %%
##These got mixed up for some reason...probably because they are in the same area and have the same value
commmuting_merged_df.set_value(921,"City","washington")
commmuting_merged_df.set_value(923,"State","VA")

#commmuting_merged_df["City"].str.contains(row["City"])[index3]
#cities_df
# Out:
#              City State  Minutes
# 46        atlanta    GA     31.0
# 55         austin    TX     26.4
# 106        boston    MA     32.0
# 167       chicago    IL     31.3
# 197      columbus    OH     23.5
# 219        dallas    TX     27.8
# 237        denver    CO     27.3
# 411  indianapolis    IN     24.8
# 512   los angeles    CA     30.4
# 565         miami    FL     30.6
# 922     rockville    MD     34.6
# 610     nashville    TN     27.0
# 627        newark    NJ     32.7
# 628      new york    NY     37.1
# 689  philadelphia    PA     31.5
# 697    pittsburgh    PA     26.5
# 727       raleigh    NC     25.4
# 921    washington    DC     34.4
# 923    alexandria    VA     34.4

# %%
commmuting_merged_df
# Out:
#              City State  Minutes
# 46        atlanta    GA     31.0
# 55         austin    TX     26.4
# 106        boston    MA     32.0
# 167       chicago    IL     31.3
# 197      columbus    OH     23.5
# 219        dallas    TX     27.8
# 237        denver    CO     27.3
# 411  indianapolis    IN     24.8
# 512   los angeles    CA     30.4
# 565         miami    FL     30.6
# 922     rockville    MD     34.6
# 610     nashville    TN     27.0
# 627        newark    NJ     32.7
# 628      new york    NY     37.1
# 689  philadelphia    PA     31.5
# 697    pittsburgh    PA     26.5
# 727       raleigh    NC     25.4
# 921    washington    DC     34.4
# 923    alexandria    VA     34.4

# %%
##Doing a merge for average number of people driving per hour (sum_driving)
##And the main dataframe (merged_df2) ##The values will be repeated in merged_df7
merged_df7 = pd.merge(sum_driving_df,merged_df2,how="right")

##Do Another merge of that merge, and the average commuting time, again, values will be repeated
merged_df9 = pd.merge(merged_df7,commmuting_merged_df, on="City",how="right")

##This is testing for the For loop
# merged_df9[merged_df9["City"]=="atlanta"]["Minutes"][0]
# merged_df9[merged_df9["City"]=="atlanta"]["Average People per Hour"][0]

merged_df9
# Out:
#              City  Average People per Hour State_x Mode  \
# 0         atlanta               244.677511      GA   MB
# 1         atlanta               244.677511      GA   HR
# 2         atlanta               244.677511      GA   DR
# 3         atlanta               244.677511      GA   DR
# 4         atlanta               244.677511      GA   VP
# 5         atlanta               244.677511      GA   CB
# 6         atlanta               244.677511      GA   VP
# 7         atlanta               244.677511      GA   SR
# 8          austin                88.412329      TX   MB
# 9          austin                88.412329      TX   VP
# 10         austin                88.412329      TX   DR
# 11         austin                88.412329      TX   CB
# 12         austin                88.412329      TX   DT
# 13         austin                88.412329      TX   YR
# 14         boston               218.371689      MA   MB
# 15         boston               218.371689      MA   DR
# 16         boston               218.371689      MA   CR
# 17         boston               218.371689      MA   HR
# 18         boston               218.371689      MA   LR
# 19         boston               218.371689      MA   RB
# 20         boston               218.371689      MA   TB
# 21         boston               218.371689      MA   MB
# 22         boston               218.371689      MA   FB
# 23         boston               218.371689      MA   VP
# 24        chicago               400.628425      IL   MB
# 25        chicago               400.628425      IL   HR
# 26        chicago               400.628425      IL   CR
# 27       columbus                97.877511      OH   MB
# 28       columbus                97.877511      OH   DR
# 29       columbus                97.877511      OH   VP
# ..            ...                      ...     ...  ...
# 85       new york              1207.603425      NY   FB
# 86       new york              1207.603425      NY   MB
# 87       new york              1207.603425      NY   MB
# 88       new york              1207.603425      NY   FB
# 89       new york              1207.603425      NY   FB
# 90       new york              1207.603425      NY   FB
# 91     alexandria               551.476256      VA   MB
# 92     alexandria               551.476256      VA   DT
# 93     alexandria               551.476256      VA   CR
# 94   philadelphia               252.000571      PA   MB
# 95   philadelphia               252.000571      PA   DR
# 96   philadelphia               252.000571      PA   CR
# 97   philadelphia               252.000571      PA   HR
# 98   philadelphia               252.000571      PA   SR
# 99   philadelphia               252.000571      PA   TB
# 100    pittsburgh               109.564612      PA   MB
# 101    pittsburgh               109.564612      PA   DR
# 102    pittsburgh               109.564612      PA   LR
# 103    pittsburgh               109.564612      PA   IP
# 104    pittsburgh               109.564612      PA   VP
# 105       raleigh                55.625000      NC   DT
# 106       raleigh                55.625000      NC   MB
# 107       raleigh                55.625000      NC   DR
# 108       raleigh                55.625000      NC   MB
# 109    washington               551.476256      DC   MB
# 110    washington               551.476256      DC   HR
# 111    washington               551.476256      DC   DR
# 112    washington               551.476256      DC   DT
# 113    washington               551.476256      DC   MB
# 114    washington               551.476256      DC   SR
#
#      Average Speed (mi/hr)  Passengers per Hour  \
# 0                    12.33                29.75
# 1                    26.56                85.81
# 2                    15.40                 1.58
# 3                    17.47                 1.71
# 4                    42.11                 6.87
# 5                    25.57                15.00
# 6                    51.14                 4.70
# 7                     4.83                52.42
# 8                    11.85                23.39
# 9                    35.87                 4.99
# 10                   13.16                 1.72
# 11                   18.34                13.50
# 12                   21.83                 3.85
# 13                   23.80                64.32
# 14                   10.37                51.59
# 15                   13.99                 1.72
# 16                   29.98                43.10
# 17                   15.27               114.67
# 18                    9.24                91.79
# 19                    8.43                90.04
# 20                    9.05                46.19
# 21                   11.70                24.57
# 22                    9.79                62.31
# 23                   39.71                 5.16
# 24                    9.08                44.98
# 25                   17.93                59.59
# 26                   30.45                50.57
# 27                   12.14                18.31
# 28                   19.35                 1.55
# 29                   47.48                 5.36
# ..                     ...                  ...
# 85                   11.52                44.99
# 86                    8.43                39.08
# 87                   26.89                26.54
# 88                    9.80              1165.53
# 89                   12.73                86.90
# 90                   10.43               169.66
# 91                    8.48                19.98
# 92                   14.33                 3.01
# 93                   31.94                60.73
# 94                   10.03                46.01
# 95                   10.27                 1.63
# 96                   21.10                39.49
# 97                   18.53               109.32
# 98                    8.53                66.47
# 99                    8.49                63.03
# 100                  13.12                33.78
# 101                  14.86                 2.38
# 102                  12.73                47.68
# 103                   2.34                99.36
# 104                  38.10                 9.05
# 105                   5.45                 0.95
# 106                  12.82                22.87
# 107                  21.65                 1.63
# 108                  10.44                44.58
# 109                  10.15                32.92
# 110                  24.60                78.61
# 111                   9.89                 1.14
# 112                  23.46                 1.42
# 113                   5.72                24.85
# 114                   4.31                36.73
#
#      Average Passenger Trip Length (mi)  Directional Route Miles  \
# 0                                  4.25                   1672.2
# 1                                  6.63                     96.1
# 2                                 10.91                      0.0
# 3                                 13.16                      0.0
# 4                                 41.16                      0.0
# 5                                 25.19                    270.4
# 6                                 62.38                      0.0
# 7                                  0.84                      2.7
# 8                                  4.07                   1084.8
# 9                                 34.13                      0.0
# 10                                 7.96                      0.0
# 11                                16.25                    192.2
# 12                                 6.54                      0.0
# 13                                16.42                     64.2
# 14                                 2.63                   1493.5
# 15                                 7.79                      0.0
# 16                                20.63                    776.1
# 17                                 3.51                     76.3
# 18                                 2.66                     51.0
# 19                                 1.83                     10.4
# 20                                 2.17                     21.6
# 21                                 2.32                     80.0
# 22                                 8.20                     38.4
# 23                                38.84                      0.0
# 24                                 2.45                   1538.3
# 25                                 6.06                    207.8
# 26                                22.37                    975.0
# 27                                 3.83                   1099.4
# 28                                10.78                      0.0
# 29                                47.82                      0.0
# ..                                  ...                      ...
# 85                                 4.07                     13.2
# 86                                 2.94                    811.0
# 87                                 7.47                     33.0
# 88                                 5.20                     10.4
# 89                                 1.95                     15.7
# 90                                 2.20                     11.0
# 91                                 2.25                    111.1
# 92                                 5.11                      0.0
# 93                                33.49                    173.6
# 94                                 3.22                   2503.1
# 95                                 6.98                      0.0
# 96                                12.59                    446.9
# 97                                 4.44                     74.9
# 98                                 2.43                     82.9
# 99                                 1.94                     30.6
# 100                                4.27                   1644.2
# 101                                7.85                      0.0
# 102                                3.75                     49.6
# 103                                0.12                      0.2
# 104                               27.66                      0.0
# 105                                6.55                      0.0
# 106                                4.39                    408.1
# 107                               13.44                      0.0
# 108                                2.03                    312.9
# 109                                3.12                   2356.5
# 110                                5.92                    234.2
# 111                                7.87                      0.0
# 112                               16.51                      0.0
# 113                                1.10                     43.0
# 114                                0.94                      3.8
#
#      Average Trip Time State_y  Minutes
# 0            20.681265      GA     31.0
# 1            14.977410      GA     31.0
# 2            42.506494      GA     31.0
# 3            45.197481      GA     31.0
# 4            58.646402      GA     31.0
# 5            59.108330      GA     31.0
# 6            73.187329      GA     31.0
# 7            10.434783      GA     31.0
# 8            20.607595      TX     26.4
# 9            57.089490      TX     26.4
# 10           36.291793      TX     26.4
# 11           53.162486      TX     26.4
# 12           17.975263      TX     26.4
# 13           41.394958      TX     26.4
# 14           15.216972      MA     32.0
# 15           33.409578      MA     32.0
# 16           41.287525      MA     32.0
# 17           13.791749      MA     32.0
# 18           17.272727      MA     32.0
# 19           13.024911      MA     32.0
# 20           14.386740      MA     32.0
# 21           11.897436      MA     32.0
# 22           50.255363      MA     32.0
# 23           58.685470      MA     32.0
# 24           16.189427      IL     31.3
# 25           20.278862      IL     31.3
# 26           44.078818      IL     31.3
# 27           18.929160      OH     23.5
# 28           33.426357      OH     23.5
# 29           60.429655      OH     23.5
# ..                 ...     ...      ...
# 85           21.197917      NY     37.1
# 86           20.925267      NY     37.1
# 87           16.667906      NY     37.1
# 88           31.836735      NY     37.1
# 89            9.190888      NY     37.1
# 90           12.655801      NY     37.1
# 91           15.919811      VA     34.4
# 92           21.395673      VA     34.4
# 93           62.911709      VA     34.4
# 94           19.262213      PA     31.5
# 95           40.778968      PA     31.5
# 96           35.800948      PA     31.5
# 97           14.376686      PA     31.5
# 98           17.092614      PA     31.5
# 99           13.710247      PA     31.5
# 100          19.527439      PA     26.5
# 101          31.695828      PA     26.5
# 102          17.674784      PA     26.5
# 103           3.076923      PA     26.5
# 104          43.559055      PA     26.5
# 105          72.110092      NC     25.4
# 106          20.546022      NC     25.4
# 107          37.247113      NC     25.4
# 108          11.666667      NC     25.4
# 109          18.443350      DC     34.4
# 110          14.439024      DC     34.4
# 111          47.745197      DC     34.4
# 112          42.225064      DC     34.4
# 113          11.538462      DC     34.4
# 114          13.085847      DC     34.4
#
# [115 rows x 11 columns]

# %%
##We do not need this column
del merged_df9["State_y"]

# %%
##This got a lot more complicated, this creates a two dictionaries of weights. The first one considers just public transportation. The second one incorporates commmuting driving as a factor
##The reason why it is separated is because it is apparant that most people drive to work. So the commuting driving heavily affects the overall score. 
weighted_scores_with_drive = {}
weighted_scores_without_drive_dict = {}
list_of_weighteddf = []
for index1,row1 in cities_df.iterrows():
    for index2,row2 in merged_df2.iterrows():
        d1 = merged_df2[merged_df2["City"]==row1["City"]]
        d2 = merged_df2[merged_df2["City"]==row1["City"]]
        sum2 = d2["Passengers per Hour"].sum()
        sum1 = d1["Passengers per Hour"].sum()+merged_df9[merged_df9["City"]==row1["City"]]["Average People per Hour"][merged_df9.index[merged_df9["City"]==row1["City"]][0]]
        d2["Percentage of Passengers utilized"] = d2["Passengers per Hour"]/sum2
        d1["Percentage of Passengers utilized"] = d1["Passengers per Hour"]/sum1
        d2["weighted"] = d2["Percentage of Passengers utilized"]*d2["Average Trip Time"]
        d1.set_value(index2+1,"Percentage of Passengers utilized",merged_df9[merged_df9["City"]==row1["City"]]["Average People per Hour"][merged_df9.index[merged_df9["City"]==row1["City"]][0]]/sum1)
        d1["weighted"] = d1["Percentage of Passengers utilized"]*d1["Average Trip Time"]
        d1.set_value(index2+1,"weighted", merged_df9[merged_df9["City"]==row1["City"]]["Average People per Hour"][merged_df9.index[merged_df9["City"]==row1["City"]][0]]/sum1*merged_df9[merged_df9["City"]==row1["City"]]["Minutes"][merged_df9.index[merged_df9["City"]==row1["City"]][0]])
        weighted_score_with_drive = d1["weighted"].sum()
        weighted_score_wo_drive = d2["weighted"].sum()
        weighted_scores_with_drive[row1["City"]] = weighted_score_with_drive
        weighted_scores_without_drive_dict[row1["City"]]= weighted_score_wo_drive
        list_of_weighteddf.append(d1)

# %%
##More Testing for the for loop
#merged_df9.index[merged_df9["City"]=="chicago"][0]


#merged_df9[merged_df9["City"]==row1["City"]]["Average People per Hour"][merged_df9.index[merged_df9["City"]==row1["City"]][0]]
#index2.dtype
#merged_df9[merged_df9["City"]==row1["City"]]["Average People per Hour"][merged_df9.index[merged_df9["City"]==row1["City"]][0]]/sum1
#merged_df9[merged_df9["City"]==row1["City"]]["Average People per Hour"]

#merged_df9[merged_df9["City"]==row1["City"]]["Average People per Hour"][merged_df9.index[merged_df9["City"]==row1["City"]][0]]/sum1*merged_df9[merged_df9["City"]==row1["City"]]["Minutes"][merged_df9.index[merged_df9["City"]==row1["City"]][0]]

# %%
weighted_scores_with_drive
# Out:
# {'alexandria': 36.48303954956693,
#  'atlanta': 26.689175339020807,
#  'austin': 33.033972738811045,
#  'boston': 24.47018951688783,
#  'chicago': 30.058118822448613,
#  'columbus': 24.55312216155005,
#  'dallas': 28.254638253743792,
#  'denver': 26.79359451892987,
#  'indianapolis': 24.28920990648313,
#  'los angeles': 26.692047319115282,
#  'miami': 25.566191695281486,
#  'nashville': 33.520134553976156,
#  'new york': 30.64052599570794,
#  'newark': 30.092175069311324,
#  'philadelphia': 24.00981086106867,
#  'pittsburgh': 17.166834197877012,
#  'raleigh': 20.151047718865293,
#  'rockville': 33.04361892625478,
#  'washington': 29.697949825493055}

# %%
weighted_scores_without_drive_dict
# Out:
# {'alexandria': 50.20433495432511,
#  'atlanta': 21.35778709500006,
#  'austin': 38.28157924159262,
#  'boston': 21.374400390113678,
#  'chicago': 26.851125785357873,
#  'columbus': 28.64023462741277,
#  'dallas': 29.028636680967267,
#  'denver': 26.370065267255523,
#  'indianapolis': 21.803712180111916,
#  'los angeles': 22.230721081748168,
#  'miami': 18.77171860071003,
#  'nashville': 38.67404125805223,
#  'new york': 26.481222300518358,
#  'newark': 22.340253057725,
#  'philadelphia': 18.21894742117664,
#  'pittsburgh': 11.847798106079916,
#  'raleigh': 15.981792105012396,
#  'rockville': 16.782884310618066,
#  'washington': 14.936926176679231}

# %%
merged_df_rank_with_drive = pd.DataFrame.from_dict(weighted_scores_with_drive, orient = "index")


merged_df_rank_with_drive = merged_df_rank_with_drive.rename(columns={0: 'Score with Driving'})
merged_df_rank_with_drive.reset_index(level=0, inplace=True)
merged_df_rank_with_drive = merged_df_rank_with_drive.rename(columns = {"index":"City"})

merged_df_rank_with_drive.sort_values("Score with Driving")
# Out:
#             City  Score with Driving
# 16    pittsburgh           17.166834
# 17       raleigh           20.151048
# 15  philadelphia           24.009811
# 7   indianapolis           24.289210
# 2         boston           24.470190
# 4       columbus           24.553122
# 9          miami           25.566192
# 0        atlanta           26.689175
# 8    los angeles           26.692047
# 6         denver           26.793595
# 5         dallas           28.254638
# 18    washington           29.697950
# 3        chicago           30.058119
# 12        newark           30.092175
# 13      new york           30.640526
# 1         austin           33.033973
# 10     rockville           33.043619
# 11     nashville           33.520135
# 14    alexandria           36.483040

# %%
merged_df_rank_wo_drive = pd.DataFrame.from_dict(weighted_scores_without_drive_dict, orient = "index")

merged_df_rank_wo_drive = merged_df_rank_wo_drive.rename(columns={0: 'Score without Driving'})
merged_df_rank_wo_drive.reset_index(level=0, inplace=True)
merged_df_rank_wo_drive = merged_df_rank_wo_drive.rename(columns = {"index":"City"})

merged_df_rank_wo_drive.sort_values("Score without Driving")
# Out:
#             City  Score without Driving
# 16    pittsburgh              11.847798
# 18    washington              14.936926
# 17       raleigh              15.981792
# 10     rockville              16.782884
# 15  philadelphia              18.218947
# 9          miami              18.771719
# 0        atlanta              21.357787
# 2         boston              21.374400
# 7   indianapolis              21.803712
# 8    los angeles              22.230721
# 12        newark              22.340253
# 6         denver              26.370065
# 13      new york              26.481222
# 3        chicago              26.851126
# 4       columbus              28.640235
# 5         dallas              29.028637
# 1         austin              38.281579
# 11     nashville              38.674041
# 14    alexandria              50.204335

# %%
merged_df_rank_with_drive_max = max(merged_df_rank_with_drive["Score with Driving"])
merged_df_rank_with_drive_min = min(merged_df_rank_with_drive["Score with Driving"])
merged_df_rank_with_drive_range = merged_df_rank_with_drive_max-merged_df_rank_with_drive_min
merged_df_rank_with_drive["Degree_score"]=1.0

# %%
for index,row in merged_df_rank_with_drive.iterrows():
    score = abs((row["Score with Driving"]-merged_df_rank_with_drive_max)/merged_df_rank_with_drive_range*-10)
    score = round(score,1)
    merged_df_rank_with_drive.set_value(index,"Degree_score",score)

# %%
merged_df_rank_with_drive.sort_values("Degree_score",ascending=False)
# Out:
#             City  Score with Driving  Degree_score
# 16    pittsburgh           17.166834          10.0
# 17       raleigh           20.151048           8.5
# 15  philadelphia           24.009811           6.5
# 7   indianapolis           24.289210           6.3
# 2         boston           24.470190           6.2
# 4       columbus           24.553122           6.2
# 9          miami           25.566192           5.7
# 8    los angeles           26.692047           5.1
# 0        atlanta           26.689175           5.1
# 6         denver           26.793595           5.0
# 5         dallas           28.254638           4.3
# 18    washington           29.697950           3.5
# 12        newark           30.092175           3.3
# 3        chicago           30.058119           3.3
# 13      new york           30.640526           3.0
# 1         austin           33.033973           1.8
# 10     rockville           33.043619           1.8
# 11     nashville           33.520135           1.5
# 14    alexandria           36.483040           0.0

# %%
for index,row in merged_df_rank_with_drive.iterrows():
    city = row["City"]
    state = cities_df[cities_df["City"]==city]["State"][cities_df.index[cities_df["City"]==city][0]]
    merged_df_rank_with_drive.set_value(index,"State",state)

# %%
merged_df_rank_with_drive
# Out:
#             City  Score with Driving  Degree_score State
# 0        atlanta           26.689175           5.1    GA
# 1         austin           33.033973           1.8    TX
# 2         boston           24.470190           6.2    MA
# 3        chicago           30.058119           3.3    IL
# 4       columbus           24.553122           6.2    OH
# 5         dallas           28.254638           4.3    TX
# 6         denver           26.793595           5.0    CO
# 7   indianapolis           24.289210           6.3    IN
# 8    los angeles           26.692047           5.1    CA
# 9          miami           25.566192           5.7    FL
# 10     rockville           33.043619           1.8    MD
# 11     nashville           33.520135           1.5    TN
# 12        newark           30.092175           3.3    NJ
# 13      new york           30.640526           3.0    NY
# 14    alexandria           36.483040           0.0    VA
# 15  philadelphia           24.009811           6.5    PA
# 16    pittsburgh           17.166834          10.0    PA
# 17       raleigh           20.151048           8.5    NC
# 18    washington           29.697950           3.5    DC

# %%
# cities_df[cities_df["City"]==city]["State"][cities_df.index[cities_df["City"]==city][0]]

# %%
merged_df2
# Out:
#               City State Mode  Average Speed (mi/hr)  Passengers per Hour  \
# 110        atlanta    GA   MB                  12.33                29.75
# 111        atlanta    GA   HR                  26.56                85.81
# 112        atlanta    GA   DR                  15.40                 1.58
# 113        atlanta    GA   DR                  17.47                 1.71
# 314        atlanta    GA   VP                  42.11                 6.87
# 590        atlanta    GA   CB                  25.57                15.00
# 1064       atlanta    GA   VP                  51.14                 4.70
# 3372       atlanta    GA   SR                   4.83                52.42
# 146         austin    TX   MB                  11.85                23.39
# 147         austin    TX   VP                  35.87                 4.99
# 148         austin    TX   DR                  13.16                 1.72
# 149         austin    TX   CB                  18.34                13.50
# 150         austin    TX   DT                  21.83                 3.85
# 151         austin    TX   YR                  23.80                64.32
# 33          boston    MA   MB                  10.37                51.59
# 34          boston    MA   DR                  13.99                 1.72
# 35          boston    MA   CR                  29.98                43.10
# 36          boston    MA   HR                  15.27               114.67
# 37          boston    MA   LR                   9.24                91.79
# 38          boston    MA   RB                   8.43                90.04
# 39          boston    MA   TB                   9.05                46.19
# 40          boston    MA   MB                  11.70                24.57
# 41          boston    MA   FB                   9.79                62.31
# 641         boston    MA   VP                  39.71                 5.16
# 31         chicago    IL   MB                   9.08                44.98
# 32         chicago    IL   HR                  17.93                59.59
# 108        chicago    IL   CR                  30.45                50.57
# 241       columbus    OH   MB                  12.14                18.31
# 242       columbus    OH   DR                  19.35                 1.55
# 1341      columbus    OH   VP                  47.48                 5.36
# ...            ...   ...  ...                    ...                  ...
# 91        new york    NY   FB                  11.52                44.99
# 92        new york    NY   MB                   8.43                39.08
# 1383      new york    NY   MB                  26.89                26.54
# 1395      new york    NY   FB                   9.80              1165.53
# 2929      new york    NY   FB                  12.73                86.90
# 3316      new york    NY   FB                  10.43               169.66
# 601     alexandria    VA   MB                   8.48                19.98
# 602     alexandria    VA   DT                  14.33                 3.01
# 608     alexandria    VA   CR                  31.94                60.73
# 42    philadelphia    PA   MB                  10.03                46.01
# 43    philadelphia    PA   DR                  10.27                 1.63
# 44    philadelphia    PA   CR                  21.10                39.49
# 45    philadelphia    PA   HR                  18.53               109.32
# 46    philadelphia    PA   SR                   8.53                66.47
# 47    philadelphia    PA   TB                   8.49                63.03
# 127     pittsburgh    PA   MB                  13.12                33.78
# 128     pittsburgh    PA   DR                  14.86                 2.38
# 129     pittsburgh    PA   LR                  12.73                47.68
# 130     pittsburgh    PA   IP                   2.34                99.36
# 894     pittsburgh    PA   VP                  38.10                 9.05
# 292        raleigh    NC   DT                   5.45                 0.95
# 294        raleigh    NC   MB                  12.82                22.87
# 990        raleigh    NC   DR                  21.65                 1.63
# 1293       raleigh    NC   MB                  10.44                44.58
# 19      washington    DC   MB                  10.15                32.92
# 20      washington    DC   HR                  24.60                78.61
# 21      washington    DC   DR                   9.89                 1.14
# 22      washington    DC   DT                  23.46                 1.42
# 895     washington    DC   MB                   5.72                24.85
# 900     washington    DC   SR                   4.31                36.73
#
#       Average Passenger Trip Length (mi)  Directional Route Miles  \
# 110                                 4.25                   1672.2
# 111                                 6.63                     96.1
# 112                                10.91                      0.0
# 113                                13.16                      0.0
# 314                                41.16                      0.0
# 590                                25.19                    270.4
# 1064                               62.38                      0.0
# 3372                                0.84                      2.7
# 146                                 4.07                   1084.8
# 147                                34.13                      0.0
# 148                                 7.96                      0.0
# 149                                16.25                    192.2
# 150                                 6.54                      0.0
# 151                                16.42                     64.2
# 33                                  2.63                   1493.5
# 34                                  7.79                      0.0
# 35                                 20.63                    776.1
# 36                                  3.51                     76.3
# 37                                  2.66                     51.0
# 38                                  1.83                     10.4
# 39                                  2.17                     21.6
# 40                                  2.32                     80.0
# 41                                  8.20                     38.4
# 641                                38.84                      0.0
# 31                                  2.45                   1538.3
# 32                                  6.06                    207.8
# 108                                22.37                    975.0
# 241                                 3.83                   1099.4
# 242                                10.78                      0.0
# 1341                               47.82                      0.0
# ...                                  ...                      ...
# 91                                  4.07                     13.2
# 92                                  2.94                    811.0
# 1383                                7.47                     33.0
# 1395                                5.20                     10.4
# 2929                                1.95                     15.7
# 3316                                2.20                     11.0
# 601                                 2.25                    111.1
# 602                                 5.11                      0.0
# 608                                33.49                    173.6
# 42                                  3.22                   2503.1
# 43                                  6.98                      0.0
# 44                                 12.59                    446.9
# 45                                  4.44                     74.9
# 46                                  2.43                     82.9
# 47                                  1.94                     30.6
# 127                                 4.27                   1644.2
# 128                                 7.85                      0.0
# 129                                 3.75                     49.6
# 130                                 0.12                      0.2
# 894                                27.66                      0.0
# 292                                 6.55                      0.0
# 294                                 4.39                    408.1
# 990                                13.44                      0.0
# 1293                                2.03                    312.9
# 19                                  3.12                   2356.5
# 20                                  5.92                    234.2
# 21                                  7.87                      0.0
# 22                                 16.51                      0.0
# 895                                 1.10                     43.0
# 900                                 0.94                      3.8
#
#       Average Trip Time
# 110           20.681265
# 111           14.977410
# 112           42.506494
# 113           45.197481
# 314           58.646402
# 590           59.108330
# 1064          73.187329
# 3372          10.434783
# 146           20.607595
# 147           57.089490
# 148           36.291793
# 149           53.162486
# 150           17.975263
# 151           41.394958
# 33            15.216972
# 34            33.409578
# 35            41.287525
# 36            13.791749
# 37            17.272727
# 38            13.024911
# 39            14.386740
# 40            11.897436
# 41            50.255363
# 641           58.685470
# 31            16.189427
# 32            20.278862
# 108           44.078818
# 241           18.929160
# 242           33.426357
# 1341          60.429655
# ...                 ...
# 91            21.197917
# 92            20.925267
# 1383          16.667906
# 1395          31.836735
# 2929           9.190888
# 3316          12.655801
# 601           15.919811
# 602           21.395673
# 608           62.911709
# 42            19.262213
# 43            40.778968
# 44            35.800948
# 45            14.376686
# 46            17.092614
# 47            13.710247
# 127           19.527439
# 128           31.695828
# 129           17.674784
# 130            3.076923
# 894           43.559055
# 292           72.110092
# 294           20.546022
# 990           37.247113
# 1293          11.666667
# 19            18.443350
# 20            14.439024
# 21            47.745197
# 22            42.225064
# 895           11.538462
# 900           13.085847
#
# [115 rows x 8 columns]

# %%
#merged_df2[merged_df["City"]=="atlanta"]["Average Trip Time"].mean()
# Out:
# 110     20.681265
# 111     14.977410
# 112     42.506494
# 113     45.197481
# 314     58.646402
# 590     59.108330
# 1064    73.187329
# 3372    10.434783
# Name: Average Trip Time, dtype: float64

# %%
sum2 = merged_df2[merged_df2["City"]=="chicago"]["Passengers per Hour"].sum()

# %%
merged_df2[merged_df2["City"]=="chicago"]["Average Trip Time"][31]*
# Out:
# 31     16.189427
# 32     20.278862
# 108    44.078818
# Name: Average Trip Time, dtype: float64

# %%
# Out:
#         City State Mode  Average Speed (mi/hr)  Passengers per Hour  \
# 31   chicago    IL   MB                   9.08                44.98
# 32   chicago    IL   HR                  17.93                59.59
# 108  chicago    IL   CR                  30.45                50.57
#
#      Average Passenger Trip Length (mi)  Directional Route Miles  \
# 31                                 2.45                   1538.3
# 32                                 6.06                    207.8
# 108                               22.37                    975.0
#
#      Average Trip Time
# 31           16.189427
# 32           20.278862
# 108          44.078818

# %%
sum2
# Out:
# 155.14

# %%
d2["weighted"].sum()
# Out:
# 14.936926176679231

# %%
d2["Average Trip Time"].mean()
# Out:
# 24.579490609604296

# %%
plt.bar(merged_df_rank_with_drive['City'], merged_df_rank_with_drive['Score with Driving'], color='b', alpha=0.5, align="center")

# Sets the y limits of the current chart
plt.ylim(0,50)

# Give our chart some labels and a tile
plt.title("City Trip Times")
plt.xlabel("City")
plt.ylabel("Average Trip Time (weighted)")
plt.xticks(rotation=90)
# Print our chart to the screen
plt.show()

# %%
plt.bar(merged_df_rank_with_drive['City'], merged_df_rank_wo_drive['Score without Driving'], color='g', alpha=0.5, align="center")

# Sets the y limits of the current chart
#plt.ylim(0,5)

# Give our chart some labels and a tile
plt.title("City Trip Times (Public Transportation Only)")
plt.xlabel("City")
plt.ylabel("Average Trip Time (weighted)")
plt.xticks(rotation=90)
# Print our chart to the screen
plt.show()
