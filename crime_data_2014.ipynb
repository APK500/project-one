# %%
import os
import csv
import pandas as pd
import numpy as np

# %%
# data file's path:
crime_2014 = "crime_data_csvs/crime_by_city_2014.csv"

# %%
# Use Pandas to read data
crime_2014_df = pd.read_csv(crime_2014)
crime_2014_df.head(10)
# Out:
#                                 Agency State  Months  Population  \
# 0                  Phoenix Police Dept    AZ      12     1529852
# 1                   Tucson Police Dept    AZ      12      527328
# 2                   Fresno Police Dept    CA      12      513187
# 3              Los Angeles Police Dept    CA      12     3906772
# 4                San Diego Police Dept    CA      12     1368690
# 5            San Francisco Police Dept    CA      12      850294
# 6                 San Jose Police Dept    CA      12     1009679
# 7                   Denver Police Dept    CO      12      665353
# 8  Washington Metropolitan Police Dept    DC      12      658893
# 9                         Jacksonville    FL      12      856021
#
#    Violent crime total  Murder and nonnegligent Manslaughter  Legacy rape /1  \
# 0               8749.0                                   114             NaN
# 1               3443.0                                    35             NaN
# ...

# %%
# Display a statistical overview of the DataFrame (just for a test!)
crime_2014_df.describe()
# Out:
#           Months    Population  Violent crime total  \
# count  94.000000  9.400000e+01            93.000000
# mean   11.840426  6.166002e+05          4203.731183
# std     1.090558  1.004525e+06          6371.887759
# min     4.000000  5.069300e+04            89.000000
# 25%    12.000000  1.926222e+05           918.000000
# 50%    12.000000  3.381675e+05          2455.000000
# 75%    12.000000  6.622808e+05          4934.000000
# max    12.000000  8.473938e+06         50564.000000
#
#        Murder and nonnegligent Manslaughter  Legacy rape /1  Revised rape /2  \
# count                             94.000000       22.000000        72.000000
# mean                              58.180851      140.409091       346.666667
# std                               77.207159      123.671862       380.767683
# min                                0.000000       17.000000         6.000000
# 25%                               10.000000       35.000000        90.750000
# ...

# %%
# Reference columns that we wish to study!
crime_2014_df[["Agency","Violent crime total","Violent Crime rate","Robbery","Robbery rate","Property crime rate","Burglary rate"]].head()
# Out:
#                     Agency  Violent crime total  Violent Crime rate  Robbery  \
# 0      Phoenix Police Dept               8749.0               571.9     2952
# 1       Tucson Police Dept               3443.0               652.9      988
# 2       Fresno Police Dept               2382.0               464.2      781
# 3  Los Angeles Police Dept              19171.0               490.7     7949
# 4    San Diego Police Dept               5214.0               380.9     1318
#
#    Robbery rate  Property crime rate  Burglary rate
# 0         193.0               3724.3          935.8
# 1         187.4                  NaN          805.4
# 2         152.2               4111.8          919.9
# 3         203.5               2128.1          385.7
# 4          96.3               1959.0          373.7
