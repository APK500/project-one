# %%
import os
import csv
import pandas as pd
import numpy as np

# %%
# data file's path:
crime_2013 = "crime_data_csvs/crime_by_city_2013.csv"

# %%
# Use Pandas to read data
crime_2013_df = pd.read_csv(crime_2013)
crime_2013_df.head(10)
# Out:
#                                 Agency State  Months Population  \
# 0                  Phoenix Police Dept    AZ      12    1502139
# 1                   Tucson Police Dept    AZ      12     525486
# 2                   Fresno Police Dept    CA      12     508876
# 3              Los Angeles Police Dept    CA      12    3878725
# 4                San Diego Police Dept    CA      12    1349306
# 5            San Francisco Police Dept    CA      12     833863
# 6                 San Jose Police Dept    CA      12     992143
# 7                   Denver Police Dept    CO      12    648,981
# 8  Washington Metropolitan Police Dept    DC      12     646449
# 9                         Jacksonville    FL      12     845745
#
#   Violent crime total  Murder and nonnegligent Manslaughter  Legacy rape /1  \
# 0                9492                                   118           635.0
# 1                3368                                    47           216.0
# ...

# %%
# Display a statistical overview of the DataFrame (just for a test!)
crime_2013_df.describe()
# Out:
#           Months  Murder and nonnegligent Manslaughter  Legacy rape /1  \
# count  94.000000                             94.000000       45.000000
# mean   11.936170                             57.202128      239.511111
# std     0.618853                             77.345556      244.365563
# min     6.000000                              0.000000       12.000000
# 25%    12.000000                             10.500000       74.000000
# 50%    12.000000                             33.000000      160.000000
# 75%    12.000000                             68.000000      298.000000
# max    12.000000                            416.000000     1112.000000
#
#        Revised rape /2  Violent Crime rate  \
# count        48.000000           92.000000
# mean        239.687500          702.838043
# std         241.967305          383.822040
# min          21.000000           97.900000
# 25%          77.500000          398.700000
# 50%         141.000000          630.700000
# ...

# %% [markdown]
# # TBD by Group:  Which columns (crime-variables/"type"
# # do we want to study or reference??
# # When decided, we can then look at.............

# %%
# Reference a single column within a DataFrame  (based on the above)
crime_2013_df[["Agency","Violent crime total","Violent Crime rate","Robbery","Robbery rate","Property crime rate","Burglary rate"]].head()
# Out:
#                     Agency Violent crime total  Violent Crime rate Robbery  \
# 0      Phoenix Police Dept                9492               631.9    3233
# 1       Tucson Police Dept                3368               640.9    1002
# 2       Fresno Police Dept                2552               501.5     903
# 3  Los Angeles Police Dept               16524               426.0    7885
# 4    San Diego Police Dept                5303               393.0    1456
#
#    Robbery rate Property crime rate  Burglary rate
# 0         215.2                4000         1114.9
# 1         190.7                 NaN          943.3
# 2         177.4                4438         1026.4
# 3         203.3              2213.2          405.5
# 4         107.9              2351.4          471.0
